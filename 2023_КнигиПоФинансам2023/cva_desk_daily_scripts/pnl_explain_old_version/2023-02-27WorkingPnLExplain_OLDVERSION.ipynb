# %%
import ps, ps_utils
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from tqdm import tqdm
from collections import defaultdict
ps_utils.switch_to_prod_pvlss()
no_skew_model = 'HybridLGM1FDupireLocalVolatilityModel'
skew_model = 'HybridCheyette1FactorLocalVolatilityModel'
import warnings
warnings.filterwarnings("ignore") 

from ps_utils.env import ps
import numpy as np
from ps_utils import env, market, analytics, pricing
import pandas as pd

from typing import Union, Optional, Dict, List
PsObject = Union[ps.Message, ps.GlobalID]


ps_utils.global_algo_id()
# Out:
# [ERROR] 2023-07-03 15:17:53,132 - You do not have xbbg installed, some functionality will not be available
# [INFO] 2023-07-03 15:17:53,882 - Nothing to do: current environment is already prod_pvlss
# '6c21bbf749e70ca1d53f365a33d8b184691c53c2'

# %%
def get_df(response_hashid, isPrev):
    r = ps.get(response_hashid)
    mas_cpty=[]
    mas_resp_hash=[]
    mas_bcva=[]
    for i,el in enumerate(r.Result):
        mas_cpty.append(ps.get(el._nonce)['_Counterparty'])
        mas_resp_hash.append(el._id)
        try:
            mas_bcva.append(el.Result['BCVA'])
        except:
            mas_bcva.append(np.nan)
    df=pd.DataFrame({'Cpty':mas_cpty, 'Resp_Hash_tek':mas_resp_hash,'BCVA_tek':mas_bcva})
    if isPrev:
        df.rename(columns={'Resp_Hash_tek':'Resp_Hash_prev','BCVA_tek':'BCVA_prev'},inplace=True)
    return df

resp_prev=ps.get('e32436c7fea7522996787a6f66670afb91147792')
resp_tek=ps.get('7ac40ba63ecb042f46d138d3ad8133668e1b20a1')

dtprev = resp_prev['Result'][0]['Request']['Model']['MarketDataSet']['AsOfDate'].date().strftime("%Y-%m-%d")
dttek = resp_tek['Result'][0]['Request']['Model']['MarketDataSet']['AsOfDate'].date().strftime("%Y-%m-%d")

df_prev=get_df(resp_prev, isPrev=True)
df_tek=get_df(resp_tek, isPrev=False)
df=df_prev.merge(df_tek, on='Cpty', how='outer')

newoldcpties=pd.read_excel('OldNewCpties.xlsx')
newoldcpties=newoldcpties[newoldcpties['Metric']=='BCVA']
df=df.merge(newoldcpties,on='Cpty',how='left')

print("PrevBCVA=",df_prev['BCVA_prev'].sum())
print("TekBCVA=",df_tek['BCVA_tek'].sum())
print("diff=",df_tek['BCVA_tek'].sum()-df_prev['BCVA_prev'].sum())

#mask=pd.read_excel('tmp_Names30Cpties.xlsx')['Cpty'].values
#mask=list(map(lambda x: x in mask, df['Cpty']))
#dfmasked=df[mask]
#dfmasked['BCVA_diff']=dfmasked['BCVA_tek']-dfmasked['BCVA_prev']
#dfmasked.head(5)

mask1na=df['BCVA_prev'].isna()
mask2na=df['BCVA_tek'].isna()

# print("New cpties:",df[mask1na]['BCVA_tek'].sum(), df[mask1na]['Cpty'].unique())
# print("Expired cpties:",df[mask2na]['BCVA_prev'].sum(),df[mask2na]['Cpty'].unique())

new_cpties=df[mask1na]
expired_cpties=df[mask2na]
print("New cpties old book:",new_cpties[new_cpties['Old/New']=='Old']['BCVA_tek'].sum(), new_cpties[new_cpties['Old/New']=='Old']['Cpty'].unique())
print("Expired cpties old book:",expired_cpties[expired_cpties['Old/New']=='Old']['BCVA_tek'].sum(), expired_cpties[expired_cpties['Old/New']=='Old']['Cpty'].unique())
print("New cpties new book:",new_cpties[new_cpties['Old/New']=='New']['BCVA_tek'].sum(), new_cpties[new_cpties['Old/New']=='New']['Cpty'].unique())
print("Expired cpties new book:",expired_cpties[expired_cpties['Old/New']=='New']['BCVA_tek'].sum(), expired_cpties[expired_cpties['Old/New']=='New']['Cpty'].unique())


maskna=~(mask1na^mask2na)
dfmasked=df
#dfmasked=df[maskna]
#dfmasked.reset_index()
dfmasked['abs_old_BCVA']=np.abs(dfmasked['BCVA_prev'])
dfmasked['diff_BCVA']=dfmasked['BCVA_tek']-dfmasked['BCVA_prev']
dfmasked['abs_diff_BCVA']=np.abs(dfmasked['diff_BCVA'])
#dfmasked=dfmasked[dfmasked['abs_old_BCVA']>0].reset_index(drop=True)

# newoldcpties=pd.read_excel('OldNewCpties.xlsx')
# newoldcpties=newoldcpties[newoldcpties['Metric']=='BCVA']
# dfmasked=dfmasked.merge(newoldcpties,on='Cpty',how='left')
dfmasked_old=dfmasked[dfmasked['Old/New']=='Old'].reset_index(drop=True)
dfmasked_new=dfmasked[dfmasked['Old/New']=='New'].reset_index(drop=True)
print("AmtCpties to run pnl explain:",len(dfmasked))
print("Total diff masked=",dfmasked['diff_BCVA'].sum())
print("Old book diff masked=",dfmasked_old['diff_BCVA'].sum())
print("New book diff masked=",dfmasked_new['diff_BCVA'].sum())
dfmasked.sort_values(by='abs_diff_BCVA', ascending=False).head()
# Out:
# PrevBCVA= -15535754.216342846
# TekBCVA= -16834206.219399303
# diff= -1298452.0030564573
# New cpties old book: -692.5560564246293 ['KPMAL' 'SARST' 'VTMEK']
# Expired cpties old book: 0.0 []
# New cpties new book: -158073.74323213787 ['VBBBB' 'DRUZA' 'LUBOS' 'SAMZE' 'KKKKS' 'SBKRR' 'SBTKB' 'SZNOV' 'FRMMK'
#  'MEDUN' 'MBVVL' 'IMLEN' 'STREI' 'TKSSS' 'PPPPR' 'TEHUG' 'DVAMR' 'SZVDK'
#  'NIKKA' '1AAMB' 'ZARPO' 'VVVBB' 'TESVE' 'PRMTP' 'KOARS' '1AAOH' 'NNNNH'
#  'DVBRR' 'RUSAN' 'GKSOK' 'NNNNV' 'CBTTT' 'RPBUN' 'UUBBB' 'MEBZZ' 'NIZZZ'
#  'ARHZZ' 'PVBSM' 'VEDER' 'METRA' 'SBBKO' 'MULTT' 'CCCBR' 'ZZZAD' 'DVBVV'
#  'VINOO' 'VECHB' 'TISHA' 'AVALL' '1AAPC' 'VETMG' 'SZZVE' 'KARTR' 'TSDEV'
#  'MLRDD' 'BAYDM' 'SZASS' '1AAIA' 'PVBZZ' 'ALFOR' 'SEVZZ' 'PRKIM' 'VVBBB'
#  '1AAMT' 'KOMME' 'UZBSS' 'AGRRB' 'STIUN' 'PROKC' 'OMGBG' 'AROMR' 'MKMIH'
#  'MOBLL' '1AAHU' 'RUUTT' 'GOLAH' 'SFTTR' 'SLAKO' 'SENDO' 'AGRUR' 'UZBRR'
#  'NNPPP' 'DDDDP' 'TDVKT' 'VOLEG' 'AHNIZ' 'ROSHH' 'PARKZ' 'TPKSA' 'SSBBT'
#  'BBSSS' 'KRACN' 'MGSTT' 'BBZTM' 'SZBNK' 'MSSSS' 'ELEEE' '1AAMQ' 'SZCHH'
#  'GRUNV' 'SUGTK' 'TEKSL' 'VERBI' 'PVLLL' 'NASHD' 'AAAAU' 'TRIVO' 'EKASC'
#  'NEVAM' 'MZMZZ' 'OOOSK' 'PPOOR' 'BONOL' 'ZAVBU' 'ELEAP' 'ERTEN' 'SRBMF'
#  'FRPPP' 'MOLLO' 'SRBKL' 'SRBHR' 'TEEPP' 'SZPPP' 'KOTLN' 'MSKSK' 'TUMOL'
#  'MBZZZ' 'ZTIME' 'VITTT' 'YASTL' 'TZZZZ' 'SZDEL' 'AKSIM' 'TSSAD' 'SZGGP'
#  'SAMSK' 'SZKRR' 'SELEE' '1AANS' 'OONPK' 'VOTRA' 'FERON' 'VVVVB' 'SKPPP'
#  '1AAMH' 'DDPPP' 'DEMER' 'KTSSS' 'SRBPD' 'SBSSS' 'STRRE' 'SZSTT' 'VEGSA'
#  'SZGEF' 'SPDOV' 'KORMZ' 'DDDDS' 'ARRRS' 'LLAGR' 'DDVVV' 'ALISA' 'VITPL'
#  'ALNZG' 'INDPA' 'BARIO' '1AAIT' 'VIDEO' 'VVTEX' 'SZRAG' 'UZTTT' 'KETTT'
#  '1AANW' 'PRFFF' 'RAAAO' 'NADDO' 'EKHRT' 'SRBPC' 'METOO' 'AVRSZ' 'UCHUM'
#  'MKAST' 'BBBBS' 'FTRRO' 'STEVR' 'TKTEN' 'SZSIG' 'CAPSZ' 'RMOTR' 'MINKZ']
# Expired cpties new book: 0.0 []
# AmtCpties to run pnl explain: 1558
# Total diff masked= -1077037.1097806045
# Old book diff masked= 317151.4520488685
# New book diff masked= -1394188.561829473
#        Cpty                            Resp_Hash_prev     BCVA_prev  \
# 148   MBKRK  2a4192b5e015b51922a5e933fe2acf6a471566a9    -76,291.18
# 905   SZSTP  e5ddfaa22c3b1b4ad616a9132b08878781ffcfa5   -238,988.04
# 24    VNEKB  7a2628c146b6e80a40df7138fc9b3f84c8514c45  1,136,744.64
# 1332  SIBRH  a1e5e9b110fe3b524183ead7001a93831452b83d -3,987,017.71
# 622   GRIDD  5bef469f6f853db80f2ca1525109618072899d27   -617,309.69
#
#                                  Resp_Hash_tek      BCVA_tek Old/New Metric  \
# 148   3b65536b9e6199fc234d2cff6a10277329347d9a   -754,693.07     New   BCVA
# 905   323ad21a867f2ad9d5f80e287fc0ba64109d7b1a   -602,618.38     New   BCVA
# 24    a3fecb7990fccdfa6835daccc5aeed747e05a108  1,395,366.67     Old   BCVA
# 1332  723e0e37ae76b3bcf70dc0da7a1217578946f557 -4,153,685.13     New   BCVA
# 622   621068af3ba71981333cde25514e402060e563e2   -763,577.64     New   BCVA
#
#       abs_old_BCVA   diff_BCVA  abs_diff_BCVA
# 148      76,291.18 -678,401.88     678,401.88
# 905     238,988.04 -363,630.33     363,630.33
# 24    1,136,744.64  258,622.02     258,622.02
# 1332  3,987,017.71 -166,667.42     166,667.42
# 622     617,309.69 -146,267.95     146,267.95

# %%
dfmasked[dfmasked['Old/New'].isna()]
# Out:
#         Cpty                            Resp_Hash_prev  BCVA_prev  \
# 46     FOTON  7ae6da71d0319c420c40512c49dfd5d92c50260a       0.00
# 54     EVKOK  91d49264d65f01f5b2226d1dcb1c3d35ffebf5bb       0.00
# 130    PTROL  23470201a664482c3b9512f3913574c8c99755a7        NaN
# 156    FSKSS  74eb94743c82645733b888619da15768dc1a46cb        NaN
# 254    MBDDR  1d7d6ec66c4f897d3341e7511db44c7710af6f45        NaN
# 551    ARNEV  5df211c47188c2f7cfc73e79f245071e03c7fed6       0.00
# 584    KEVRP  87c34a0303d9f7024ea4a67b20a28c672f3c9eed       8.41
# 601    URBEN  02921cec135c9d5b7eee756fc55e862f47ec9dd0       0.00
# 671    RKOOO  27ff9483d75abe901ec98a1a4d359f39a11e6175       0.01
# 708    FUDSS  17f038d850c78382de4e400ad56b78c7a3b177b9       0.00
# 738    MTSSS  582a0fc5d7904992440406bc1c7634db8adf4588  25,181.63
# 765    MDSBR  0c12e4d72aa6e5d29662753d8b5752a4a62d7dc1       0.00
# 974    KCHKS  2bfe4d73f2d9abaa7bbdc19c4af0685d90c859fd       0.00
# 1012   NERUS  83ed646a3bdbc99b82e01cf668bc64d8bf841026       0.00
# 1184  VOENSK  dd0bdd4222dd6de4a9687cbbdd1803903bbf3674   7,238.86
# 1384   SZDEM                                       NaN        NaN
# 1445   KCVET                                       NaN        NaN
# 1457   SOLFE                                       NaN        NaN
# 1463   AVGUT                                       NaN        NaN
# 1479   MBMMR                                       NaN        NaN
# 1497   DIEKS                                       NaN        NaN
#
#                                  Resp_Hash_tek   BCVA_tek Old/New Metric  \
# 46                                         NaN        NaN     NaN    NaN
# 54                                         NaN        NaN     NaN    NaN
# 130   2ca5f7284132b179895b4e54a5bbccb6563d5cca        NaN     NaN    NaN
# 156   21b104ff94217758fc2a0c39c931b72dcd8c2af6        NaN     NaN    NaN
# 254   72110ae3b9d0e6a35985661c4d68a7f8b5a7e2df        NaN     NaN    NaN
# 551                                        NaN        NaN     NaN    NaN
# 584                                        NaN        NaN     NaN    NaN
# 601                                        NaN        NaN     NaN    NaN
# 671                                        NaN        NaN     NaN    NaN
# 708                                        NaN        NaN     NaN    NaN
# 738   49027e68c906174fc0ac26e93b10c232a2dfd857        NaN     NaN    NaN
# 765                                        NaN        NaN     NaN    NaN
# 974                                        NaN        NaN     NaN    NaN
# 1012                                       NaN        NaN     NaN    NaN
# 1184  0a4a61292f03421440aaca61ddac541823a8e9c4        NaN     NaN    NaN
# 1384  e0e4bdd44ee87a5276d0235746f59c754e341aea -30,219.68     NaN    NaN
# 1445  6fd5d420283b0b7f89a050b121643d30b27b8776        NaN     NaN    NaN
# 1457  4dcf4f280adc9c938ca0239f3eb3bce81cbddd8c        NaN     NaN    NaN
# 1463  575c005bc7d9e44f7a4702443c316bdb1250661b        NaN     NaN    NaN
# 1479  6aa254331c91b4a898b330a7758174b2373d78bd        NaN     NaN    NaN
# 1497  556108e4c8e72bcb33e5340f6175a0a0fc260474        NaN     NaN    NaN
#
#       abs_old_BCVA  diff_BCVA  abs_diff_BCVA
# 46            0.00        NaN            NaN
# 54            0.00        NaN            NaN
# 130            NaN        NaN            NaN
# 156            NaN        NaN            NaN
# 254            NaN        NaN            NaN
# 551           0.00        NaN            NaN
# 584           8.41        NaN            NaN
# 601           0.00        NaN            NaN
# 671           0.01        NaN            NaN
# 708           0.00        NaN            NaN
# 738      25,181.63        NaN            NaN
# 765           0.00        NaN            NaN
# 974           0.00        NaN            NaN
# 1012          0.00        NaN            NaN
# 1184      7,238.86        NaN            NaN
# 1384           NaN        NaN            NaN
# 1445           NaN        NaN            NaN
# 1457           NaN        NaN            NaN
# 1463           NaN        NaN            NaN
# 1479           NaN        NaN            NaN
# 1497           NaN        NaN            NaN

# %%
print("all=",dfmasked['BCVA_prev'].sum())
print("old=",dfmasked_old['BCVA_prev'].sum())
print("new=",dfmasked_new['BCVA_prev'].sum())
print("old+new=",dfmasked_old['BCVA_prev'].sum()+dfmasked_new['BCVA_prev'].sum())
# Out:
# all= -16287112.087532878
# old= -6015092.59075744
# new= -10272019.496775437
# old+new= -16287112.087532878

# %%
dfmasked[dfmasked['Cpty']=='SZKOT']
# Out:
#       Cpty                            Resp_Hash_prev  BCVA_prev  \
# 119  SZKOT  aa09da4efbba09f7db32eb1cf79608006a669f7e  -5,641.53
#
#                                 Resp_Hash_tek  BCVA_tek Old/New Metric  \
# 119  c1b7268b576092d082172e479655c1d075d5b0d0 -6,513.62     New   BCVA
#
#      abs_old_BCVA  diff_BCVA  abs_diff_BCVA
# 119      5,641.53    -872.09         872.09

# %%
dfmasked[dfmasked['Cpty']=='FNKOP']
# Out:
#       Cpty                            Resp_Hash_prev  BCVA_prev  \
# 446  FNKOP  b31f1e27e0def47d7567ee0ee9b0cb77a0fac6c1  22,363.95
#
#                                 Resp_Hash_tek  BCVA_tek Old/New Metric  \
# 446  912a5c445c132f80d7559c4d115aeebd5175d73f  3,792.05     New   BCVA
#
#      abs_old_BCVA  diff_BCVA  abs_diff_BCVA
# 446     22,363.95 -18,571.90      18,571.90

# %%
algo_id = '833aa9286a2951a0eac3fb38913d6990435e5c4c'


reqv_tek=ps.get(resp_tek._nonce)
reqv_prev=ps.get(resp_prev._nonce)


queries = ['BCVA']
big_request = ps_utils.prepare_big_request_for_pnl(reqv_tek, reqv_prev, algo_id,'USD', queries)

b = ps_utils.run_generic_revaluation_based_metric_change_explain_batch(big_request, algo_id, True)

ps.put(b)
ps_utils.env.logger.info(f'Result id is {b._id}')

# df = pd.DataFrame(columns=['MetricType', 'Category', 'Counterparty', 'Value'])
# for result in a:
#     for metric in queries:
#         for category in result[metric]:
#             df = pd.concat([df, pd.DataFrame([{
#                 'MetricType': metric,
#                 'Category': category,
#                 'Counterparty': result.Request['_Counterparty'],
#                 'Value': result[metric][category]}])])

# df.to_excel('PnLExplain.xlsx', index=False)
# Out:
# [INFO] 2023-07-03 15:29:12,637 - Removing failed cpties
# [INFO] 2023-07-03 15:29:48,164 - Cpties removed
# [INFO] 2023-07-03 15:29:48,165 - PNL Explain started
# [INFO] 2023-07-03 15:29:48,166 - Doing some preparations
# [INFO] 2023-07-03 15:29:48,167 - Converting market data to canonical format
# [INFO] 2023-07-03 15:29:48,712 - Converting done
# [INFO] 2023-07-03 15:29:48,714 - Collecting dependencies
# [INFO] 2023-07-03 15:45:32,773 - Market dependencies collected
# [INFO] 2023-07-03 15:45:32,774 - Preparations done
# [INFO] 2023-07-03 15:45:32,775 - Calculating Total
# [INFO] 2023-07-03 15:48:59,242 - Total calculated
# [INFO] 2023-07-03 15:48:59,243 - Calculating StaticDataSet change effect
# [INFO] 2023-07-03 15:48:59,272 - StaticDataSet change not needed
# [INFO] 2023-07-03 15:48:59,273 - Calculating Product change effect
# [INFO] 2023-07-03 15:49:21,663 - Product change calculated
# [INFO] 2023-07-03 15:49:21,665 - Model change effect calculation
# [INFO] 2023-07-03 15:49:21,666 - NumeraireCurrency change effect calculation
# [INFO] 2023-07-03 15:49:21,877 - NumeraireCurrency change not needed
# [INFO] 2023-07-03 15:49:21,878 - TypeName change effect calculation
# [INFO] 2023-07-03 15:49:21,888 - TypeName change not needed
# [INFO] 2023-07-03 15:49:21,889 - Theta effect calculation
# [INFO] 2023-07-03 15:51:42,280 - Theta effect done
# [INFO] 2023-07-03 15:51:42,281 - Processing CreditCurves.RUB_SBER_OFZ_SNR_CR
# [INFO] 2023-07-03 15:51:42,285 - Collecting requests
# [INFO] 2023-07-03 15:53:59,345 - Requests collected. Request=16a1605b70fd07c5b711dcdc5b71e3263468c387. PrevRequest=ff94fc1c8478785cb5c24bac06f7efaa021d6187
# [INFO] 2023-07-03 15:54:32,456 - Processing CreditCurves.RUB_SBER_OFZ_SNR_CR done
# [INFO] 2023-07-03 15:54:32,457 - Processing CreditCurves.RUB_MINFIN_OFZ
# [INFO] 2023-07-03 15:54:32,459 - Collecting requests
# [INFO] 2023-07-03 15:56:22,154 - Requests collected. Request=9fff433f89f7ba326812eb05195608367974f711. PrevRequest=0761f11667415f823aa7df8eaef6b5efebca18cb
# [INFO] 2023-07-03 15:56:55,065 - Processing CreditCurves.RUB_MINFIN_OFZ done
# [INFO] 2023-07-03 15:56:55,066 - Processing CreditCurves.USD_KAZKH_SNR_CR
# [INFO] 2023-07-03 15:56:55,072 - Collecting requests
# [INFO] 2023-07-03 15:56:55,193 - Requests collected. Request=617002cb0fdbd396bca677ca345b797735fdd87b. PrevRequest=70f22583a47f1300b085f9bb776d3cd309f45751
# [INFO] 2023-07-03 15:56:55,239 - Processing CreditCurves.USD_KAZKH_SNR_CR done
# [INFO] 2023-07-03 15:56:55,240 - Processing Fixings.RUB_KEY_RATE
# [INFO] 2023-07-03 15:56:55,241 - Collecting requests
# [INFO] 2023-07-03 15:58:36,186 - Requests collected. Request=22fe5a50348d7734caeac2e225a392e2133f5a22. PrevRequest=f2b7bd7d4aa11c5fb692c2532b4e053b63e6848e
# [INFO] 2023-07-03 15:59:07,990 - Processing Fixings.RUB_KEY_RATE done
# [INFO] 2023-07-03 15:59:07,992 - Processing Fixings.USDRUB
# [INFO] 2023-07-03 15:59:07,995 - Collecting requests
# [INFO] 2023-07-03 15:59:12,628 - Requests collected. Request=e1233e9debab89f4b2eccfe5fc32fa89cb1c5286. PrevRequest=5965b6942d02556aaf2cfe18b02abc569aa382b9
# [INFO] 2023-07-03 15:59:14,116 - Processing Fixings.USDRUB done
# [INFO] 2023-07-03 15:59:14,117 - Processing Fixings.CNHRUB
# [INFO] 2023-07-03 15:59:14,119 - Collecting requests
# [INFO] 2023-07-03 15:59:17,873 - Requests collected. Request=f77f7a4b31193eb6c4182858fe0794073cf2a2b4. PrevRequest=9e081d2120a318dd200b314ca6b1dc1de5ffc346
# [INFO] 2023-07-03 15:59:19,053 - Processing Fixings.CNHRUB done
# [INFO] 2023-07-03 15:59:19,054 - Processing Fixings.EURRUB
# [INFO] 2023-07-03 15:59:19,056 - Collecting requests
# [INFO] 2023-07-03 15:59:21,897 - Requests collected. Request=a24f7410145b77e8085bb53ea29f62a96835cd67. PrevRequest=061d0a393c5fdf16a0d68541158c9d4a2432ea5b
# [INFO] 2023-07-03 15:59:22,805 - Processing Fixings.EURRUB done
# [INFO] 2023-07-03 15:59:22,806 - Processing Fixings.XAURUB
# [INFO] 2023-07-03 15:59:22,807 - Collecting requests
# [INFO] 2023-07-03 15:59:23,374 - Requests collected. Request=de889f9adeea98062e57178a8980bdbc27b97c59. PrevRequest=164174fed11884b01688fa04469ae0a5c63173b9
# [INFO] 2023-07-03 15:59:23,563 - Processing Fixings.XAURUB done
# [INFO] 2023-07-03 15:59:23,564 - Processing Fixings.EUR_EURIBOR_3M
# [INFO] 2023-07-03 15:59:23,565 - Collecting requests
# [INFO] 2023-07-03 15:59:23,908 - Requests collected. Request=0b7fa594ce0a73ffa535d9bbdf92adc93375e68d. PrevRequest=6a7e75184c5c91b5bc85357301ee655958de4951
# [INFO] 2023-07-03 15:59:24,047 - Processing Fixings.EUR_EURIBOR_3M done
# [INFO] 2023-07-03 15:59:24,049 - Processing Fixings.RUB_MOSPRIME_3M
# [INFO] 2023-07-03 15:59:24,050 - Collecting requests
# [INFO] 2023-07-03 15:59:24,281 - Requests collected. Request=8090e11cdf5e5356fe3d99791beb125ce10f9fe3. PrevRequest=159e550f879267ab0f89880d782d4d5cf8e52d52
# [INFO] 2023-07-03 15:59:24,354 - Processing Fixings.RUB_MOSPRIME_3M done
# [INFO] 2023-07-03 15:59:24,355 - Processing Fixings.JPYRUB
# [INFO] 2023-07-03 15:59:24,356 - Collecting requests
# [INFO] 2023-07-03 15:59:24,461 - Requests collected. Request=5395f0a01b544fe52154eb18a0281120ebdbe911. PrevRequest=a4455e7dd839b7a33911ee1b2d00c7d108f0e2eb
# [INFO] 2023-07-03 15:59:24,509 - Processing Fixings.JPYRUB done
# [INFO] 2023-07-03 15:59:24,510 - Processing Fixings.CHFRUB
# [INFO] 2023-07-03 15:59:24,511 - Collecting requests
# [INFO] 2023-07-03 15:59:24,618 - Requests collected. Request=b48dcff150e85fe8b383c2db5ad54011c7e11bff. PrevRequest=5de83fb88d6f131f82671e12ec00054492b6d9da
# [INFO] 2023-07-03 15:59:24,664 - Processing Fixings.CHFRUB done
# [INFO] 2023-07-03 15:59:24,666 - Processing RatesCurvesBundles.RUB_KEY_RATE
# [INFO] 2023-07-03 15:59:24,668 - Collecting requests
# [INFO] 2023-07-03 16:01:19,838 - Requests collected. Request=06c28d3072049f091ad36031d500c4b8098125c1. PrevRequest=6da4320f52924484ed338d9b1e08de9e4c234910
# [INFO] 2023-07-03 16:01:52,505 - Processing RatesCurvesBundles.RUB_KEY_RATE done
# [INFO] 2023-07-03 16:01:52,506 - Processing RatesCurvesBundles.RUB_RUONIA_OIS
# [INFO] 2023-07-03 16:01:52,510 - Collecting requests
# [INFO] 2023-07-03 16:03:42,800 - Requests collected. Request=668e5435e54a30e7c60cc3504b21b0a54ff7f477. PrevRequest=6da4320f52924484ed338d9b1e08de9e4c234910
# [INFO] 2023-07-03 16:04:15,309 - Processing RatesCurvesBundles.RUB_RUONIA_OIS done
# [INFO] 2023-07-03 16:04:15,310 - Processing RatesCurvesBundles.RUB_SOFR
# [INFO] 2023-07-03 16:04:15,313 - Collecting requests
# [INFO] 2023-07-03 16:06:09,204 - Requests collected. Request=30387ed2967263335b298506309cc953e38dc5cb. PrevRequest=6da4320f52924484ed338d9b1e08de9e4c234910
# [INFO] 2023-07-03 16:06:44,478 - Processing RatesCurvesBundles.RUB_SOFR done
# [INFO] 2023-07-03 16:06:44,479 - Processing RatesCurvesBundles.USD_SOFR
# [INFO] 2023-07-03 16:06:44,483 - Collecting requests
# [INFO] 2023-07-03 16:08:35,566 - Requests collected. Request=c2953b4a34898c2feaa5f2f833c0473a999d99cb. PrevRequest=6da4320f52924484ed338d9b1e08de9e4c234910
# [INFO] 2023-07-03 16:09:12,483 - Processing RatesCurvesBundles.USD_SOFR done
# [INFO] 2023-07-03 16:09:12,485 - Processing RatesCurvesBundles.USD_LIBOR_3M
# [INFO] 2023-07-03 16:09:12,488 - Collecting requests
# [INFO] 2023-07-03 16:09:16,801 - Requests collected. Request=1c972d824931401b9afed40267faab0a8b5528dd. PrevRequest=5965b6942d02556aaf2cfe18b02abc569aa382b9
# [INFO] 2023-07-03 16:09:18,156 - Processing RatesCurvesBundles.USD_LIBOR_3M done
# [INFO] 2023-07-03 16:09:18,157 - Processing RatesCurvesBundles.USD_XCCY
# [INFO] 2023-07-03 16:09:18,158 - Collecting requests
# [INFO] 2023-07-03 16:09:22,485 - Requests collected. Request=db0e351256e58ccf6cffd864d3ba303b122e0d69. PrevRequest=5965b6942d02556aaf2cfe18b02abc569aa382b9
# [INFO] 2023-07-03 16:09:24,056 - Processing RatesCurvesBundles.USD_XCCY done
# [INFO] 2023-07-03 16:09:24,057 - Processing RatesCurvesBundles.CNH_FX
# [INFO] 2023-07-03 16:09:24,058 - Collecting requests
# [INFO] 2023-07-03 16:09:27,890 - Requests collected. Request=d913d69a0b120a9364a697f5c265c0a5c26f8a42. PrevRequest=9e081d2120a318dd200b314ca6b1dc1de5ffc346
# [INFO] 2023-07-03 16:09:29,269 - Processing RatesCurvesBundles.CNH_FX done
# [INFO] 2023-07-03 16:09:29,270 - Processing RatesCurvesBundles.CNH_SOFR
# [INFO] 2023-07-03 16:09:29,271 - Collecting requests
# [INFO] 2023-07-03 16:09:33,051 - Requests collected. Request=4d64dde2bbeab54853bad78d6f461477ac1eb00f. PrevRequest=9e081d2120a318dd200b314ca6b1dc1de5ffc346
# [INFO] 2023-07-03 16:09:34,521 - Processing RatesCurvesBundles.CNH_SOFR done
# [INFO] 2023-07-03 16:09:34,523 - Processing RatesCurvesBundles.EUR_EURIBOR_6M
# [INFO] 2023-07-03 16:09:34,524 - Collecting requests
# [INFO] 2023-07-03 16:09:38,307 - Requests collected. Request=05da2f7051205ca98e8b855226e50c54a5d3a543. PrevRequest=061d0a393c5fdf16a0d68541158c9d4a2432ea5b
# [INFO] 2023-07-03 16:09:39,424 - Processing RatesCurvesBundles.EUR_EURIBOR_6M done
# [INFO] 2023-07-03 16:09:39,425 - Processing RatesCurvesBundles.EUR_XCCY
# [INFO] 2023-07-03 16:09:39,426 - Collecting requests
# [INFO] 2023-07-03 16:09:42,238 - Requests collected. Request=d3f6d9d360d72c917b9a894b95be71962b17517e. PrevRequest=061d0a393c5fdf16a0d68541158c9d4a2432ea5b
# [INFO] 2023-07-03 16:09:43,304 - Processing RatesCurvesBundles.EUR_XCCY done
# [INFO] 2023-07-03 16:09:43,305 - Processing RatesCurvesBundles.EUR_RUB
# [INFO] 2023-07-03 16:09:43,307 - Collecting requests
# [INFO] 2023-07-03 16:09:46,243 - Requests collected. Request=09d40c094045d74045c987a3aa1b5e1919f2acb0. PrevRequest=061d0a393c5fdf16a0d68541158c9d4a2432ea5b
# [INFO] 2023-07-03 16:09:47,317 - Processing RatesCurvesBundles.EUR_RUB done
# [INFO] 2023-07-03 16:09:47,319 - Processing RatesCurvesBundles.XAU_USD
# [INFO] 2023-07-03 16:09:47,320 - Collecting requests
# [INFO] 2023-07-03 16:09:48,000 - Requests collected. Request=292cd83cfd3a3c926885e87207c6352221009983. PrevRequest=164174fed11884b01688fa04469ae0a5c63173b9
# [INFO] 2023-07-03 16:09:48,204 - Processing RatesCurvesBundles.XAU_USD done
# [INFO] 2023-07-03 16:09:48,206 - Processing RatesCurvesBundles.EUR_EURIBOR_3M
# [INFO] 2023-07-03 16:09:48,207 - Collecting requests
# [INFO] 2023-07-03 16:09:48,553 - Requests collected. Request=a38e91db8993e50fff0bc58a5e8b9e88efe54ace. PrevRequest=6a7e75184c5c91b5bc85357301ee655958de4951
# [INFO] 2023-07-03 16:09:48,657 - Processing RatesCurvesBundles.EUR_EURIBOR_3M done
# [INFO] 2023-07-03 16:09:48,658 - Processing RatesCurvesBundles.RUB_MOSPRIME_3M
# [INFO] 2023-07-03 16:09:48,660 - Collecting requests
# [INFO] 2023-07-03 16:09:48,838 - Requests collected. Request=5c1891cc2428a59f25ca8cfaff7b935401d2ea0b. PrevRequest=159e550f879267ab0f89880d782d4d5cf8e52d52
# [INFO] 2023-07-03 16:09:48,912 - Processing RatesCurvesBundles.RUB_MOSPRIME_3M done
# [INFO] 2023-07-03 16:09:48,913 - Processing RatesCurvesBundles.JPY_XCCY
# [INFO] 2023-07-03 16:09:48,914 - Collecting requests
# [INFO] 2023-07-03 16:09:49,004 - Requests collected. Request=0fbc37d96afada774958a9e04c9c265ce8acea00. PrevRequest=a4455e7dd839b7a33911ee1b2d00c7d108f0e2eb
# [INFO] 2023-07-03 16:09:49,047 - Processing RatesCurvesBundles.JPY_XCCY done
# [INFO] 2023-07-03 16:09:49,048 - Processing RatesCurvesBundles.CHF_XCCY
# [INFO] 2023-07-03 16:09:49,050 - Collecting requests
# [INFO] 2023-07-03 16:09:49,140 - Requests collected. Request=7b5adfc7778545c26dbc94873fe186be18d24242. PrevRequest=5de83fb88d6f131f82671e12ec00054492b6d9da
# [INFO] 2023-07-03 16:09:49,185 - Processing RatesCurvesBundles.CHF_XCCY done
# [INFO] 2023-07-03 16:09:49,186 - Processing RatesCurvesBundles.CHF_LIBOR_6M
# [INFO] 2023-07-03 16:09:49,187 - Collecting requests
# [INFO] 2023-07-03 16:09:49,291 - Requests collected. Request=08d55f821b826da9959c0fd8aa41cf653b1f494e. PrevRequest=5de83fb88d6f131f82671e12ec00054492b6d9da
# [INFO] 2023-07-03 16:09:49,334 - Processing RatesCurvesBundles.CHF_LIBOR_6M done
# [INFO] 2023-07-03 16:09:49,335 - Processing Spots.USDRUB
# [INFO] 2023-07-03 16:09:49,337 - Collecting requests
# [INFO] 2023-07-03 16:11:42,425 - Requests collected. Request=7b08bf265e6412ff36c9dc06aa2b90ab52a748e1. PrevRequest=6da4320f52924484ed338d9b1e08de9e4c234910
# [INFO] 2023-07-03 16:12:16,318 - Processing Spots.USDRUB done
# [INFO] 2023-07-03 16:12:16,320 - Processing Spots.CNHRUB
# [INFO] 2023-07-03 16:12:16,322 - Collecting requests
# [INFO] 2023-07-03 16:12:20,164 - Requests collected. Request=544aa6d1c08875a6d1b9613760598ee3d9aaf5ff. PrevRequest=9e081d2120a318dd200b314ca6b1dc1de5ffc346
# [INFO] 2023-07-03 16:12:21,389 - Processing Spots.CNHRUB done
# [INFO] 2023-07-03 16:12:21,391 - Processing Spots.EURRUB
# [INFO] 2023-07-03 16:12:21,392 - Collecting requests
# [INFO] 2023-07-03 16:12:24,539 - Requests collected. Request=9441675e3fc21c1d5c702b6d08b3ce2ba147d6f9. PrevRequest=061d0a393c5fdf16a0d68541158c9d4a2432ea5b
# [INFO] 2023-07-03 16:12:25,434 - Processing Spots.EURRUB done
# [INFO] 2023-07-03 16:12:25,436 - Processing Spots.XAURUB
# [INFO] 2023-07-03 16:12:25,437 - Collecting requests
# [INFO] 2023-07-03 16:12:26,044 - Requests collected. Request=54723e1d09727b10bd8a006c85bcded226a1ad37. PrevRequest=164174fed11884b01688fa04469ae0a5c63173b9
# [INFO] 2023-07-03 16:12:26,247 - Processing Spots.XAURUB done
# [INFO] 2023-07-03 16:12:26,248 - Processing Spots.JPYRUB
# [INFO] 2023-07-03 16:12:26,250 - Collecting requests
# [INFO] 2023-07-03 16:12:26,361 - Requests collected. Request=8b5b03a574bcd6123b46fb839b9411bd44a5b5cd. PrevRequest=a4455e7dd839b7a33911ee1b2d00c7d108f0e2eb
# [INFO] 2023-07-03 16:12:26,403 - Processing Spots.JPYRUB done
# [INFO] 2023-07-03 16:12:26,404 - Processing Spots.CHFRUB
# [INFO] 2023-07-03 16:12:26,405 - Collecting requests
# [INFO] 2023-07-03 16:12:26,508 - Requests collected. Request=61b6a9aa6612a7278a21068186bee28333a6492c. PrevRequest=5de83fb88d6f131f82671e12ec00054492b6d9da
# [INFO] 2023-07-03 16:12:26,551 - Processing Spots.CHFRUB done
# [INFO] 2023-07-03 16:12:26,552 - Processing VolatilitySurfaces.RUB_KEY_RATE
# [INFO] 2023-07-03 16:12:26,553 - Collecting requests
# [INFO] 2023-07-03 16:14:15,055 - Requests collected. Request=dc7a22fe41924a1504fb9e2ee688ff21614e2121. PrevRequest=6da4320f52924484ed338d9b1e08de9e4c234910
# [INFO] 2023-07-03 16:14:48,894 - Processing VolatilitySurfaces.RUB_KEY_RATE done
# [INFO] 2023-07-03 16:14:48,895 - Processing VolatilitySurfaces.USD_LIBOR_3M
# [INFO] 2023-07-03 16:14:48,898 - Collecting requests
# [INFO] 2023-07-03 16:14:53,214 - Requests collected. Request=87696a8d0199241a3b086f0fa37ce41ef61ca8bc. PrevRequest=5965b6942d02556aaf2cfe18b02abc569aa382b9
# [INFO] 2023-07-03 16:14:54,687 - Processing VolatilitySurfaces.USD_LIBOR_3M done
# [INFO] 2023-07-03 16:14:54,688 - Processing VolatilitySurfaces.USDRUB
# [INFO] 2023-07-03 16:14:54,689 - Collecting requests
# [INFO] 2023-07-03 16:14:58,946 - Requests collected. Request=7419885d8334effe700cdf70bcbedaeb6a99b3e2. PrevRequest=5965b6942d02556aaf2cfe18b02abc569aa382b9
# [INFO] 2023-07-03 16:15:00,510 - Processing VolatilitySurfaces.USDRUB done
# [INFO] 2023-07-03 16:15:00,511 - Processing VolatilitySurfaces.CNHRUB
# [INFO] 2023-07-03 16:15:00,513 - Collecting requests
# [INFO] 2023-07-03 16:15:04,320 - Requests collected. Request=e877711901969696f4e6439a3529f24ded497219. PrevRequest=9e081d2120a318dd200b314ca6b1dc1de5ffc346
# [INFO] 2023-07-03 16:15:05,529 - Processing VolatilitySurfaces.CNHRUB done
# [INFO] 2023-07-03 16:15:05,530 - Processing VolatilitySurfaces.EURRUB
# [INFO] 2023-07-03 16:15:05,532 - Collecting requests
# [INFO] 2023-07-03 16:15:08,543 - Requests collected. Request=7635c5892e25a351362cdb0196afeaa81c8a2ec4. PrevRequest=061d0a393c5fdf16a0d68541158c9d4a2432ea5b
# [INFO] 2023-07-03 16:15:09,414 - Processing VolatilitySurfaces.EURRUB done
# [INFO] 2023-07-03 16:15:09,415 - Processing VolatilitySurfaces.EUR_EURIBOR_6M
# [INFO] 2023-07-03 16:15:09,416 - Collecting requests
# [INFO] 2023-07-03 16:15:12,394 - Requests collected. Request=c1b46433cd73f34e2e093fff1145df03636c5770. PrevRequest=061d0a393c5fdf16a0d68541158c9d4a2432ea5b
# [INFO] 2023-07-03 16:15:13,270 - Processing VolatilitySurfaces.EUR_EURIBOR_6M done
# [INFO] 2023-07-03 16:15:13,272 - Processing VolatilitySurfaces.JPYRUB
# [INFO] 2023-07-03 16:15:13,273 - Collecting requests
# [INFO] 2023-07-03 16:15:13,366 - Requests collected. Request=4741c0193cc2959cc8358058ce54ab2d02e6150f. PrevRequest=a4455e7dd839b7a33911ee1b2d00c7d108f0e2eb
# [INFO] 2023-07-03 16:15:13,422 - Processing VolatilitySurfaces.JPYRUB done
# [INFO] 2023-07-03 16:15:13,424 - Processing VolatilitySurfaces.CHFRUB
# [INFO] 2023-07-03 16:15:13,425 - Collecting requests
# [INFO] 2023-07-03 16:15:13,526 - Requests collected. Request=a64e7c2e327c4a344cb66ac4a2850cb6a50040c2. PrevRequest=5de83fb88d6f131f82671e12ec00054492b6d9da
# [INFO] 2023-07-03 16:15:13,577 - Processing VolatilitySurfaces.CHFRUB done
# [INFO] 2023-07-03 16:15:13,578 - Removing unnecessary info from result and adding Unexplained
# [INFO] 2023-07-03 16:15:13,594 - Unnecessary info deleted. Job is done
# [INFO] 2023-07-03 16:16:41,845 - Result id is fdd6a7bfa6e8e529309f502b405bc671162aeee0

# %%
mas_cpties=[]
mas_pnl_explains=[]
mas_total_diff=[]
for el in b:
    mas_cpties.append(ps.get(el).Request['_Counterparty'])
    mas_pnl_explains.append(ps.get(el)._id)
    mas_total_diff.append(ps.get(el).BCVA['Total'])
    
df=pd.DataFrame({'Cpty':mas_cpties,'Explain_hash':mas_pnl_explains,'Total_diff': mas_total_diff})

newoldcpties=pd.read_excel('OldNewCpties.xlsx')
newoldcpties=newoldcpties[newoldcpties['Metric']=='BCVA']
dfotv=df.merge(newoldcpties,on='Cpty',how='left')
dfotv.to_excel(str(datetime.datetime.now().date())+"PnLExplainEdinBase" + dttek+"--"+dtprev+".xlsx")
dfotv.sort_values(by='Total_diff', ascending=False)
# Out:
#        Cpty                              Explain_hash  Total_diff Old/New  \
# 23    VNEKB  34da4f1b08d232189e6d6f0b673081d12ff0401c  258,876.35     Old
# 555   DTMIR  f56491c34f8e733bd44a5e648cca13dd2f4e6e87   73,891.08     New
# 662   EPSLL  c405c53f36f5c18fbd7f435430085b80c7a3c52d   60,112.11     New
# 1131  SZSUB  ac589aaf1c4bc12f2bdfc460f9a13bffccf60eab   35,168.75     New
# 713   SZNPV  8e0fc08dcda87db90134a0bfdd527af86face1ab   27,133.05     New
# ...     ...                                       ...         ...     ...
# 454    POLU  f986300e67f5a2e0d6c5e045df144320ee0e3032 -110,893.56     New
# 613   GRIDD  357cf6af81f1e490037f79db913b198bd5602768 -146,620.79     New
# 1332  SIBRH  086e547753f452c6b4980b71889fb5c72fc51423 -171,610.75     New
# 891   SZSTP  b377344788aee7646b6052142b4822b1eedcda37 -363,967.93     New
# 145   MBKRK  8861aaa3793670b40af319d447d7cc9e8300beca -679,492.72     New
#
#      Metric
# 23     BCVA
# 555    BCVA
# 662    BCVA
# 1131   BCVA
# 713    BCVA
# ...     ...
# 454    BCVA
# 613    BCVA
# 1332   BCVA
# 891    BCVA
# 145    BCVA
#
# [1345 rows x 5 columns]

# %%
print("Total diff=",dfotv['Total_diff'].sum())
print("Old diff=",dfotv[dfotv['Old/New']=='Old']['Total_diff'].sum())
print("New diff=",dfotv[dfotv['Old/New']=='New']['Total_diff'].sum())
# Out:
# Total diff= -495642.77057088306
# Old diff= 127187.85620497826
# New diff= -622830.6267758611

# %%
dfotv[dfotv['Cpty']=='FRTGS']
# Out:
#       Cpty                              Explain_hash  Total_diff Old/New  \
# 327  FRTGS  149af3aa4537f8de7dc62761355aaf24c273c061 -186,869.71     Old
#
#     Metric
# 327   BCVA

# %%
dfmasked[dfmasked['Cpty']=='AOEPO']
# Out:
#       Cpty                            Resp_Hash_prev  BCVA_prev  \
# 719  AOEPO  113fb9c7e32f2da8aeb2ab78b180614326525a0d   1,246.73
#
#                                 Resp_Hash_tek  BCVA_tek Old/New Metric  \
# 719  4abc86a45f425ac6dad0a33fe8a848ed979b4aaa 35,442.06     New   BCVA
#
#      abs_old_BCVA  diff_BCVA  abs_diff_BCVA
# 719      1,246.73  34,195.33      34,195.33

# %%
r=ps.get('8c5fa2503a992c07bcf34dfa4ae72f400b360dd8')
BCVA_prev_with_greeks=r.Result['BCVA']

r=ps.get(r._nonce)
r.Queries=['BCVA']
BCVA_prev_wo_greeks=ps_utils.compute(ps.put(r))['BCVA']

r=ps.get('3cf9f46b4d79a509e4ea8ed8ad298ea1d2225582')
BCVA_tek_with_greeks=r.Result['BCVA']

r=ps.get(r._nonce)
r.Queries=['BCVA']
BCVA_tek_wo_greeks=ps_utils.compute(ps.put(r))['BCVA']

print("BCVA_prev_with_greeks=",BCVA_prev_with_greeks)
print("BCVA_prev_wo_greeks=",BCVA_prev_wo_greeks)
print("BCVA_tek_with_greeks=",BCVA_tek_with_greeks)
print("BCVA_prev_wo_greeks=",BCVA_tek_wo_greeks)
print('diff_with_greeks=',BCVA_tek_with_greeks-BCVA_prev_with_greeks)
print('diff_wo_greeks=',BCVA_tek_wo_greeks-BCVA_prev_wo_greeks)
# Out:
# [INFO] 2023-03-31 10:28:29,998 - Compute:7866deca901500a7c2e65ee8598eef7f46ebe3a5->b1a58241a5b5f27983cc7bcb2f6bf1d235e44425
# [INFO] 2023-03-31 10:28:30,033 - Compute:87e40d8e419d4745a0f4ea0d137d907f2922b774->1bac25cc7505de5df64279b4b428fd5ee3b12a54
# BCVA_prev_with_greeks= -5973137.87582982
# BCVA_prev_wo_greeks= -5968275.535071469
# BCVA_tek_with_greeks= -6141979.579227808
# BCVA_prev_wo_greeks= -6155145.248670185
# diff_with_greeks= -168841.70339798834
# diff_wo_greeks= -186869.71359871607

# %%
from collections import defaultdict
def populate_dict(resp_hash,tekcpty,otv):
    r=ps.get(resp_hash)
    for el in r['BCVA']:
        if (el=='Total'):
            otv['Explained'][tekcpty]=r['BCVA'][el]
            otv['Explained'].setdefault('Total',0)
            otv['Explained']['Total']+=r['BCVA'][el]
        elif (el=='Unexplained'):
            otv['Unexplained'][tekcpty]=r['BCVA'][el]
            otv['Unexplained'].setdefault('Total',0)
            otv['Unexplained']['Total']+=r['BCVA'][el]
        elif (el=='Product'):
            otv['Product'][tekcpty]=r['BCVA'][el]
            otv['Product'].setdefault('Total',0)
            otv['Product']['Total']+=r['BCVA'][el]
        elif (el=='Model.MarketDataSet.AsOfDate'):
            otv['Carry'][tekcpty]=r['BCVA'][el]
            otv['Carry'].setdefault('Total',0)
            otv['Carry']['Total']+=r['BCVA'][el]
            
        elif (el=='ErrorBoth'):
            otv['ErrorBoth'][tekcpty]=r['BCVA'][el]
            otv['ErrorBoth'].setdefault('Total',0)
            otv['ErrorBoth']['Total']+=r['BCVA'][el]
        elif (el=='ExpiredCounterparty'):
            otv['ExpiredCounterparty'][tekcpty]=r['BCVA'][el]
            otv['ExpiredCounterparty'].setdefault('Total',0)
            otv['ExpiredCounterparty']['Total']+=r['BCVA'][el]
        elif (el=='NewCounterparty'):
            otv['NewCounterparty'][tekcpty]=r['BCVA'][el]
            otv['NewCounterparty'].setdefault('Total',0)
            otv['NewCounterparty']['Total']+=r['BCVA'][el]
        elif (el=='Rating'):
            otv['Rating'][tekcpty]=r['BCVA'][el]
            otv['Rating'].setdefault('Total',0)
            otv['Rating']['Total']+=r['BCVA'][el]
            
        elif (el.startswith('Model.MarketDataSet.CreditCurves')):
            curve=el.split('.')[3]
            if (curve not in otv['CreditCurves']):
                otv['CreditCurves'][curve]=defaultdict(defaultdict)
            otv['CreditCurves'][curve][tekcpty]=r['BCVA'][el]
            otv['CreditCurves'][curve].setdefault('Total',0)
            otv['CreditCurves'][curve]['Total']+=r['BCVA'][el]
            otv['CreditCurves'].setdefault('Total',0)
            otv['CreditCurves']['Total']+=r['BCVA'][el]
        elif (el.startswith('Model.MarketDataSet.GenericScalars')):
            otv['GenericScalars'][tekcpty]=r['BCVA'][el]
            otv['GenericScalars'].setdefault('Total',0)
            otv['GenericScalars']['Total']+=r['BCVA'][el]
        elif (el.startswith('Model.MarketDataSet.Spots')):
            pair=el.split('.')[3][0:6]
            if (pair not in otv['Spots']):
                otv['Spots'][pair]=defaultdict(defaultdict)
            otv['Spots'][pair][tekcpty]=r['BCVA'][el]
            otv['Spots'][pair].setdefault('Total',0)
            otv['Spots'][pair]['Total']+=r['BCVA'][el]
            otv['Spots'].setdefault('Total',0)
            otv['Spots']['Total']+=r['BCVA'][el]
        elif (el.startswith('Model.MarketDataSet.RatesCurvesBundles')):
            ccy=el.split('.')[3][0:3]
            curve=el.split('.')[3]
            if (ccy not in otv['Rates']):
                otv['Rates'][ccy]=defaultdict(defaultdict)
            otv['Rates'][ccy][curve][tekcpty]=r['BCVA'][el]
            otv['Rates'][ccy][curve].setdefault('Total',0)
            otv['Rates'][ccy][curve]['Total']+=r['BCVA'][el]
            otv['Rates'][ccy].setdefault('Total',0)
            otv['Rates'][ccy]['Total']+=r['BCVA'][el]
            otv['Rates'].setdefault('Total',0)
            otv['Rates']['Total']+=r['BCVA'][el]
        elif (el.startswith('Model.MarketDataSet.VolatilitySurfaces')):
            flagIsFXVol=True
            if (el.split('.')[3][3]=='_'):
                flagIsFXVol=False
            if not flagIsFXVol:
                ccy=el.split('.')[3][0:3]
                curve=el.split('.')[3]
                if (ccy not in otv['RatesVols']):
                    otv['RatesVols'][ccy]=defaultdict(defaultdict)
                otv['RatesVols'][ccy][curve][tekcpty]=r['BCVA'][el]
                otv['RatesVols'][ccy][curve].setdefault('Total',0)
                otv['RatesVols'][ccy][curve]['Total']+=r['BCVA'][el]
                otv['RatesVols'][ccy].setdefault('Total',0)
                otv['RatesVols'][ccy]['Total']+=r['BCVA'][el]
                otv['RatesVols'].setdefault('Total',0)
                otv['RatesVols']['Total']+=r['BCVA'][el]
            elif flagIsFXVol:
                pair=el.split('.')[3][0:6]
                if (pair not in otv['FXVols']):
                    otv['FXVols'][pair]=defaultdict(defaultdict)
                otv['FXVols'][pair][tekcpty]=r['BCVA'][el]
                otv['FXVols'][pair].setdefault('Total',0)
                otv['FXVols'][pair]['Total']+=r['BCVA'][el]
                otv['FXVols'].setdefault('Total',0)
                otv['FXVols']['Total']+=r['BCVA'][el]
                
                
            

    return otv

def get_pnl_table(a):
    bcva_vals=[]
    bcva_mas1=[]
    bcva_mas2=[]
    for el in a:
        if el in ['Carry','GenericScalars','Explained','Unexplained','Product']:
            bcva_mas1.append(el)
            bcva_mas2.append(el)
            bcva_vals.append(a[el]['Total'])
        elif el in ['CreditCurves','Rates','Spots','RatesVols','FXVols']:
            for k in a[el]:
                if k=='Total':
                    continue
                bcva_mas1.append(el)
                bcva_mas2.append(k)
                bcva_vals.append(a[el][k]['Total'])
        else:
            print("Bad el:",el)
    bcva_arrays = [np.array(bcva_mas1),np.array(bcva_mas2)]
    bcva_df=pd.DataFrame(bcva_vals, index=bcva_arrays)
    return bcva_df

# %%
dfotv_old=dfotv[dfotv['Old/New']=='Old'].reset_index(drop=True)
dfotv_new=dfotv[dfotv['Old/New']=='New'].reset_index(drop=True)

NAME=dfotv_old
otv=defaultdict(defaultdict)
for i in range(len(NAME)):
    otv=populate_dict(NAME['Explain_hash'][i],NAME['Cpty'][i],otv)
for el in otv:
    print(el,otv[el]['Total'])
    
    
t=get_pnl_table(otv)
print("Sum of really explained (wo unexplained)=",t.values.sum()-t.loc['Explained'].values-t.loc['Unexplained'].values)
#print("Explained=",t.loc['Explained'].values)
#print("Actual diff=",NAME['diff_BCVA'].sum())
t.to_excel(str(datetime.datetime.now().date())+"OldBookTable" + dttek+"--"+dtprev+".xlsx")
t
# Out:
# Explained 306348.476162335
# Carry 101299.95510272522
# CreditCurves -44.302705900321264
# Rates 27269.365939974487
# Spots 346692.92614100414
# RatesVols -152664.48342299595
# Unexplained -4130.510232400651
# Product -12047.460527824062
# FXVols -27.014132247220857
# Sum of really explained (wo unexplained)= [[310478.98639474]]
#                                            0
# Explained    Explained            306,348.48
# Carry        Carry                101,299.96
# CreditCurves RUB_SBER_OFZ_SNR_CR      -50.35
#              RUB_MINFIN_OFZ             6.42
#              USD_KAZKH_SNR_CR          -0.37
# Rates        RUB                   36,174.21
#              USD                     -787.77
#              CNH                   -8,119.59
#              EUR                     -117.86
#              XAU                      -73.79
#              JPY                        0.00
#              CHF                      194.17
# Spots        USDRUB                -2,471.25
#              CNHRUB               297,070.88
#              EURRUB                28,599.84
#              XAURUB                -8,087.15
#              JPYRUB                     0.00
#              CHFRUB                31,580.60
# RatesVols    RUB                 -152,664.48
#              USD                        0.00
#              EUR                        0.00
# Unexplained  Unexplained           -4,130.51
# Product      Product              -12,047.46
# FXVols       USDRUB                     0.00
#              CNHRUB                   -27.01
#              EURRUB                     0.00
#              JPYRUB                     0.00
#              CHFRUB                     0.00

# %%
otv['Product']
# Out:
# defaultdict(None,
#             {'ELKOR': -3.495413623020795,
#              'Total': -12047.460527824062,
#              'ATMEN': 2742.665187102157,
#              'VERMO': -1653.4311194951433,
#              'RTRTR': 0.0,
#              'VUBOB': 6021.069015666932,
#              'ZELRO': -41.41202638984214,
#              'RUSKZ': -12.820471529052554,
#              'NPPKV': -0.454700993932172,
#              'OLOSS': -1.4654096502218783,
#              'SERVK': 0.0,
#              'SRTNN': 0.0,
#              'PUCKO': -379.6368303609124,
#              'INTSL': 3.1749704928504343,
#              'LKTIT': 0.0,
#              'SIBSI': -107.70181787680895,
#              'SZDIN': -20.026436814173394,
#              'SRBKR': 2140.5727053626188,
#              'TDMMM': -1133.45883904797,
#              'MTLLK': -3.585188111671795,
#              'METRZ': -3803.6025907414264,
#              'ANKRR': -71.93248883172475,
#              'CVETA': 356.17004855369396,
#              'SZGRO': 1259.4964047346975,
#              'TERRI': -20.277937933029392,
#              'MURMA': 8.904180631929421,
#              'UKCIT': 93.4841074833007,
#              'OMSKV': -22.830916423931463,
#              'UKINA': -506.3308607083818,
#              'SBBLL': 0.0,
#              'PENZA': 0.0,
#              'MEDEY': -83.25061369520273,
#              'SBAGG': -41.72702391302913,
#              'REMZT': -202.6434075853771,
#              'NVSKC': 8713.688114487919,
#              'BSTIN': 0.0,
#              'MBSZM': 182.96239886804938,
#              'ZZTSZ': 0.04754541326573114,
#              'NESTR': -2.349607397471118,
#              'ESPRS': 0.0,
#              'MBOFS': 0.0,
#              'AVEFA': 0.0,
#              'SAMLI': 0.0,
#              'KONGO': -10.004883649225576,
#              'SZSTB': -17.5951235013963,
#              'URINT': -0.4127461101190164,
#              'SAVSE': 0.043768849804838084,
#              'ANUUK': 180.64437810989602,
#              'SHINN': 6.196567471761227e-05,
#              'MASTA': 0.0,
#              'AAASC': 0.0,
#              'TOMLS': -115.21716462683094,
#              'OZFFF': -63.854840757645604,
#              'IZGOR': 0.009921944413406436,
#              'NOVPK': 3.416613812845526e-05,
#              'AGOKK': 0.0,
#              'MBVVV': -218.46682862759576,
#              'RESEK': 0.0,
#              'ZHEMC': 1255.866535337821,
#              'BADDD': -0.2641463897410006,
#              'DOMSS': 0.4387052528366695,
#              'DAURI': 0.0,
#              'RASSS': 0.0,
#              'CARAW': 115.11815264392533,
#              'MOGOT': 0.02815805912720748,
#              'MASKL': 0.0,
#              'SRTDM': 0.0,
#              'STPLS': -2825.413701532276,
#              'SIBOS': -1234.0346706823675,
#              'JPMEG': 0.0,
#              'TRVIS': 100.64116983466079,
#              'DVBMM': -1546.6754269737103,
#              'KIRAN': 0.0,
#              'VKPPS': 58.371337528421634,
#              'OORAK': 0.0,
#              'RAZYU': 0.0,
#              'RDEZH': 0.0,
#              'SRTKT': 333.72234645283663,
#              'OMZIT': 42.23632522061771,
#              'APEFI': -0.43466198008144374,
#              'ORGSN': 0.0,
#              'MBSMM': 873.116765420803,
#              'OHOTN': 0.5280720036037159,
#              'LESNK': -541.0264984862304,
#              'VLTRL': 0.0,
#              'POLMA': -0.015631467124876508,
#              'ROSTX': 674.4505314091407,
#              'KOTTT': -21.685336344700772,
#              'DPPLA': 0.19595435211522272,
#              'PANMK': 650.4035051826683,
#              'SZLOG': -3.013549928116845,
#              'ATLOO': 4685.285498343362,
#              'EEELL': -0.27537808450395573,
#              'KNTTT': -55.793423285051176,
#              'KAPNE': 398.4923829708846,
#              'KSCER': 0.0,
#              'MBMMH': 0.0,
#              'SZMOL': 3107.9235802451167,
#              'INKAB': -605.2734675163568,
#              'MORED': 0.0,
#              'RAWOO': -39.675745668173136,
#              'INKOE': 0.013531572186195717,
#              'PVBST': 0.0,
#              'ZVPSM': 0.0,
#              'STSTT': -37.190639863997745,
#              'ACVIL': 0.0,
#              'DIONA': 89.30327222152266,
#              'RBGRO': 82.67849517850917,
#              'STSOD': 0.0,
#              'PRMTY': 0.0,
#              'TOROS': 3.637978807091713e-12,
#              'DELMZ': 0.0,
#              'PROTT': 0.0,
#              'SZBSS': 0.0,
#              'CEKRA': -0.01587569593591187,
#              'PIIKO': 0.08205566634144112,
#              'GALKA': 693.4092296432673,
#              'SOLGR': -65.09400281845114,
#              'FERRI': -41.576940385594014,
#              'SZTTT': 0.0,
#              'MOSNA': 106.853492930948,
#              'SRBZT': -966.3985323918823,
#              'PSSIF': -1548.4157513773926,
#              'PLTTT': 5.4717124207215875,
#              'HERGU': 0.0,
#              'MBFST': 0.0,
#              'PKAGR': 0.0,
#              'AGPOB': 0.0,
#              'LMRPL': 204.34557208323577,
#              'ISRRR': 1.1962435637160524,
#              'ABSOT': -9.610098372076841,
#              'ADMOO': 9.844025495031897,
#              'ULTRA': 0.996874865793222,
#              'ELABU': 33.95593309484869,
#              'ATOSM': 156.3452225839452,
#              'RUSLS': 0.0,
#              'RZPRO': -410.31196436707836,
#              'PRIMX': 0.0,
#              'DVKON': -84.8809679569531,
#              'DORAA': 308.41639183590564,
#              'ISTOO': 0.0,
#              'SRBZA': -479.70129810052,
#              'KARDL': -28527.3087716257,
#              'YAKHH': -44.081534985972894,
#              'SRRSS': 1.8779604832007646,
#              'TERSI': 0.0,
#              'VVBGR': 298.7916898057173,
#              'FABRS': -5.318867477723014,
#              'NBAZS': -16.53697584235174,
#              'SCORP': -5.054290447782286,
#              'ALFSZ': 340.9602397572744,
#              'VOLSM': -0.026252617390980615,
#              'PVBVR': 1127.7036019661978,
#              'SZVEK': -576.8082591365496,
#              'SBGRS': 0.31971169782447717,
#              'AGRNV': 0.0,
#              'UGOIL': -148.1001020420165,
#              'EKHOL': 0.0,
#              'ESDEV': -1582.7500614888268,
#              'DUGLK': -2.2737367544323206e-13,
#              'UTRED': 0.2072947654123709,
#              'ULUKT': -14.64908080589909,
#              'BRASO': 3.848337689904053,
#              'VINKO': 0.0,
#              'VVBMM': -20.81753287024506,
#              'VEESN': 0.0,
#              'BATBB': 0.0,
#              'ARMAA': 0.0,
#              'DARYA': 0.0,
#              'IVKZV': -331.4689506765776,
#              'GLSBB': 0.0,
#              'UPKPL': -26.380674509180608,
#              'PRTST': 31.38881418217599,
#              'RXIMS': 4.239595970746507,
#              'MOZHH': 0.0,
#              'GRJPS': 0.0,
#              'TOLMM': 830.1810552569325,
#              'FRRRM': -0.05043089590307659,
#              'ELEVK': 1.4486557878330348,
#              'AVPLU': 0.4298928572296532,
#              'LOGLB': 0.004003488776246214,
#              'GALAC': -27.41051529496501,
#              'URADD': 0.0})

# %%
dfotv_old=dfotv[dfotv['Old/New']=='Old'].reset_index(drop=True)
dfotv_new=dfotv[dfotv['Old/New']=='New'].reset_index(drop=True)

NAME=dfotv_new
otv=defaultdict(defaultdict)
for i in range(len(NAME)):
    otv=populate_dict(NAME['Explain_hash'][i],NAME['Cpty'][i],otv)
for el in otv:
    print(el,otv[el]['Total'])
    
    
t=get_pnl_table(otv)
print("Sum of really explained (wo unexplained)=",t.values.sum()-t.loc['Explained'].values-t.loc['Unexplained'].values)
#print("Explained=",t.loc['Explained'].values)
#print("Actual diff=",NAME['diff_BCVA'].sum())
t.to_excel(str(datetime.datetime.now().date())+"NewBookTable" + dttek+"--"+dtprev+".xlsx")
t
# Out:
# Explained -1402600.2202305335
# Product -1506174.5036731013
# Carry 47494.17538390769
# CreditCurves 110.51823450733997
# Rates 3107.8603782783116
# Spots 1218.1828432223172
# RatesVols -4819.0638030524615
# Unexplained 56471.42235034114
# FXVols -8.811944637044832
# Sum of really explained (wo unexplained)= [[-1459071.64258088]]
#                                              0
# Explained    Explained           -1,402,600.22
# Product      Product             -1,506,174.50
# Carry        Carry                   47,494.18
# CreditCurves RUB_SBER_OFZ_SNR_CR         -3.74
#              RUB_MINFIN_OFZ             114.26
# Rates        RUB                     -9,534.19
#              USD                      1,435.16
#              CNH                     11,941.31
#              EUR                       -171.18
#              XAU                       -563.24
# Spots        USDRUB                 360,943.87
#              CNHRUB                -708,263.54
#              EURRUB                 352,435.28
#              XAURUB                  -3,897.43
# RatesVols    RUB                     -4,819.06
#              USD                          0.00
#              EUR                          0.00
# Unexplained  Unexplained             56,471.42
# FXVols       CNHRUB                      -8.81
#              USDRUB                       0.00
#              EURRUB                      -0.00

# %%
otv['Product']
# Out:
# defaultdict(None,
#             {'1AAMG': 8.73758613486369,
#              'Total': -1506174.5036731013,
#              'SZSMM': 1.294008688424694,
#              'REMKS': 10.33272988518857,
#              'SZPPB': 0.0,
#              'MSGRP': -19990.656968139985,
#              'SZNKK': -145.2963104865339,
#              'NIMZK': 121.10095687562624,
#              'MLKPK': 331.90938998507363,
#              'ZONDX': 53.953737064808266,
#              'SZPRS': -10210.14435465636,
#              'SZKOT': -12.874172799284679,
#              'MELSA': 2.409562016026902,
#              'MBKRK': -701005.0215828404,
#              'SZDED': -4064.5037618183133,
#              'KLINN': 4.321444816926132,
#              'MZTON': 0.0,
#              'PVBMV': -6057.466429022832,
#              'TVGRR': 2.0353419181923478,
#              'JDKEN': 0.0,
#              'TTEHH': 4.010131319730704,
#              'GLOFA': -1965.7168325052555,
#              'PRIVP': 3.428568549546071,
#              'GKCTT': -1036.7823630802013,
#              '1AALN': -0.021192800033103865,
#              '1AAIY': -0.08541748587968456,
#              'BERPR': 16.383888321326545,
#              'RETRO': -83.3175146506801,
#              'SZSSK': -9.098590563802645,
#              'MBKRR': -6220.364044500468,
#              'PRMIT': 6.4009510444677815,
#              'SIBES': -14.615407418966754,
#              'KTTNK': -581.7550695846467,
#              'ROSMI': -3203.070939728512,
#              'TTCFL': -0.05546707201612544,
#              'GKSTT': -16.58076142360187,
#              'PVBSR': -4.356941570179451,
#              'SBPZK': 0.0,
#              'KZKKK': -202.8314942452247,
#              'SRSRT': 0.0,
#              'SZLEN': -4573.011272459429,
#              'MBAVK': 7.0306779438954266,
#              'UVISS': 26.17514857313688,
#              'ZZZBW': -16296.788913795477,
#              'OOZON': -1630.1665780566846,
#              'MBGGR': 1945.5185050404916,
#              'BATEH': 583.1786897523125,
#              'TVSTR': -5598.990385875626,
#              'VVBCC': 0.025382797419943065,
#              'BRVIN': 0.0,
#              'UBPPS': 3128.8437856798228,
#              'OFPRO': 0.04328098098803568,
#              'GLTTT': 100.80403625537505,
#              'SZATT': -3423.215274716751,
#              'MBVRV': -3.776896081153609,
#              'ZZZAV': 0.0,
#              'ZLTSL': -1810.8354146658303,
#              'MBFRZ': -18563.37828079608,
#              'SBPLS': 0.0,
#              'ORGAN': 15.292080744904009,
#              'POLU': 0.0,
#              'ATKOM': 0.5129309059262717,
#              'YNTEH': 60.76153511178518,
#              'SPEVK': -4524.4313361062395,
#              'SBSZZ': -26.52468075953402,
#              'EFDSZ': -7230.192760924075,
#              'EFIRN': 83.93618020661233,
#              'PTKKL': 4.093279056819259,
#              'AVTMM': -1444.5071731767093,
#              'PRPRF': 27.883653914396945,
#              'VIKRK': -4122.194814203011,
#              'GRSZA': -3462.373780781034,
#              'DTMIR': 32018.809467668034,
#              '1AAKH': 0.13129931172779408,
#              'CHAIK': -19.256466387581696,
#              'KUBAS': 0.0,
#              'SIGRU': -67.02757887747237,
#              'LESAZ': -1382.204929056918,
#              'SRKLD': -3741.033624644871,
#              'SOCHS': 61.958526611613706,
#              'GRIDD': -167129.02702869195,
#              'AGGRR': -2.4098776526397296,
#              'LOGIS': 0.0,
#              'YZHHH': -229.97782263834563,
#              'POLSZ': 0.0,
#              'OSZAL': 89.53326104195912,
#              'ZZZCE': 0.0,
#              'TRNZT': 0.1473627711705111,
#              '1AAIL': 2.331418207460162,
#              'RUSEZ': -9256.502688543125,
#              'SZSOO': -19887.13563802382,
#              '1AANC': 0.803908374398822,
#              'GIPGS': 18.233759028529676,
#              'SZNPV': 25930.072523918272,
#              'MRTSR': 0.0,
#              'MOBTT': 0.7463163532438966,
#              'SZKVV': 812.7973662242166,
#              'SZNVS': -0.2351844529614624,
#              'PARKP': -1193.3052856064378,
#              'SZURL': 174.3063946884813,
#              'PVCMU': 356.5834113124295,
#              'POBBB': 0.0,
#              'BELKV': -528.0960420108984,
#              'ROSNB': -73683.58509235457,
#              'MBNNK': -165.00514484276027,
#              'SRBRN': -94.35322328144679,
#              'SBIRV': 676.812424030838,
#              'RRABA': -533.7969336873325,
#              'NPOST': -4.22669925667229,
#              'TDGRS': 18.08520664724415,
#              'SZREE': -947.8393188619384,
#              'AGIMP': 120.59242625068498,
#              'SRBFT': -2.3012613460411018,
#              'PVBDD': -0.6285530652206148,
#              'GALTS': 193.20705140444056,
#              'UVASZ': -3058.265179652279,
#              'SADCO': -5.37117851185042,
#              'RUKAT': 0.0,
#              'ASOOL': 68.14750473335016,
#              'SZSTP': -380578.4400837983,
#              'VEKKK': 0.0,
#              '1AAII': 0.3706667776886121,
#              'MBFSN': -50552.741001628645,
#              'YZBMM': -203.90745612386104,
#              'SRBGB': -764.2519510986274,
#              'LEBOO': -23.295989778761864,
#              'ROSTL': 592.6713350493555,
#              'MBKMK': -8358.524946112317,
#              'SOUAG': 0.0,
#              'VZVZL': 2.9132303158621653,
#              'DIAME': -543.1485040267486,
#              'DUBRA': 15.723430985170864,
#              'IKSST': 15.32858428527561,
#              'ALSKM': 0.0,
#              'AEVTK': 218.5222947701459,
#              'SRSKK': 1325.321648698841,
#              'EXPEX': -82.73891990089061,
#              'FLAAA': -13580.231852272236,
#              'FGRPP': 71.89596986157994,
#              'UKBGR': 497.96497193228106,
#              'VERSZ': 2963.9256836681843,
#              'UBDMM': 1.5957142222217495,
#              'SZLYY': 8655.733763575332,
#              'KRHZG': 0.0,
#              'UBTPP': 6.759279108772929,
#              'POZVA': -8867.64267148191,
#              'KUBMA': -918.3695173202286,
#              'SZVYS': -2.4885585917163553,
#              'NOVRP': -47973.19516662439,
#              'STLKA': 172.89215395665838,
#              'SZSUB': 33626.218983303,
#              'ULGRA': 299.19145086649587,
#              'GRALU': 180.43753831868332,
#              'AQURI': -7.814160646042637,
#              'YZBRR': -241.88484257241464,
#              'UNKKK': 0.0,
#              'TDZGO': 0.11962768961783699,
#              'PVBNS': 60.15524010805463,
#              'REMZO': -316.06155192005684,
#              'SZSMU': -376.135576911817,
#              'ALUHH': 279.60832332715563,
#              'SZAKV': 0.0,
#              'KOGRU': -5727.213985649058,
#              'RIMEK': -501.0272432796655,
#              'TDKAI': 45.93265699667198,
#              'VLHZA': -1.2953744402659595,
#              'SZMGP': -107.91172136362383,
#              'DFREE': 0.0,
#              'BKROS': 0.0,
#              'TRESZ': 3268.2501050611518,
#              'VERRR': 1037.1199894626566,
#              'SZKSI': 552.1517867017538,
#              'KILLR': -450.1726499596366,
#              'SUEKO': -357.53726619697227,
#              'NPPTK': 33.48717856936227,
#              'SVETR': -3212.0552458647817,
#              'PNKNN': 2.9397696432240306,
#              'SKSOU': -14.117279287042038,
#              'ARDTZ': -0.5885373877181337,
#              'AZMMM': 5488.093582439105,
#              'DVBFF': -936.7203948662486,
#              'FERNT': -16300.20159605657,
#              'SOLLL': -2.3014572375548124,
#              'LIDTE': 20.993903818209958,
#              'SZGRR': 17824.47546308913,
#              'FITTT': -64.16432571891585,
#              'NATEK': 3.7526664903921105})

# %%
dfotv_old[dfotv_old['Cpty']=='KARDL']
# Out:
#       Cpty                              Explain_hash  Total_diff Old/New  \
# 585  KARDL  6c0638bbdedb607755532fe030a653ec92b9b28c  -28,735.74     Old
#
#     Metric
# 585   BCVA

# %%
dfotv_new[dfotv_new['Cpty']=='SIBRH']
# Out:
#       Cpty                              Explain_hash  Total_diff Old/New  \
# 576  SIBRH  086e547753f452c6b4980b71889fb5c72fc51423 -171,610.75     New
#
#     Metric
# 576   BCVA

# %%
m=0
for el in dfotv_old['Explain_hash']:
    el=ps.get(el)
    try:
        m+=el['BCVA']['Rating']
    except:
        continue
m
# Out:
# 0

# %%
m=0
for el in dfotv_new['Explain_hash']:
    el=ps.get(el)
    try:
        m+=el['BCVA']['Rating']
    except:
        continue
m
# Out:
# 0

# %%
s1=set()
r=ps.get('65c171951c71cee1f774b10e3396231db03d074b')
for el in r.Products:
    s1.add(el['_ContractID'])
s2=set()
r=ps.get('316a8c84ede11278b1d42d7e872a3737aba20ad9')
for el in r.Products:
    s2.add(el['_ContractID'])
print(len(s1))
print(len(s2))
print(s1.difference(s2))
print(s2.difference(s1))
# Out:
# 16
# 14
# {'38392628', '38392640'}
# set()

# %%
len(s2)
# Out:
# 117

# %%
r=ps.get('4886dbdb4b0fae6aa5f9fcf529843214f6b242c3')
s24=set()
for el in r.Products:
    s24.add(el._id)
s24
# Out:
# {'05ffd67d562e1cb25a46ea8f0494beabc38521b5',
#  '1f008a983e9d48fc591af28b07d50e8e35a1c01a',
#  '263af42506e0504c5a6308c3feac69ee453bb391',
#  '2cf60df268ba4263e2f392fac7b1e7e161aebf4d',
#  '2fff5c380cfcd684abc84bc6183e74f1be9df49a',
#  '39c2efff94df0c5d7cc9da36e309a6a0bf603df7',
#  '3dec782bdf1035ef340d7b2bfef657b37988c80c',
#  '690cd72c1bfb54f736cf5592097744dc2ea1b3ed',
#  '72324f5cdb3fa4863bb2dc6b2a9175de0f40cc0c',
#  '8eeb4ac8f815016ca1a67203e60b980b783adb33',
#  '9d58781a594705aa053f6a39a239f098af1a3b46',
#  'ec73d26cd3bd259fc3e12d8564ac84d99b61d1c8'}

# %%
r=ps.get('6439fe9b20c630f2a8aae56e875de3be1b3286f8')
s25=set()
for el in r.Products:
    s25.add(el._id)
s25
# Out:
# {'05ffd67d562e1cb25a46ea8f0494beabc38521b5',
#  '1f008a983e9d48fc591af28b07d50e8e35a1c01a',
#  '263af42506e0504c5a6308c3feac69ee453bb391',
#  '2cf60df268ba4263e2f392fac7b1e7e161aebf4d',
#  '2fff5c380cfcd684abc84bc6183e74f1be9df49a',
#  '3dec782bdf1035ef340d7b2bfef657b37988c80c',
#  '690cd72c1bfb54f736cf5592097744dc2ea1b3ed',
#  '72324f5cdb3fa4863bb2dc6b2a9175de0f40cc0c',
#  '8bb8c2f288ee2afdfb47010dc162ccd6d1062f7d',
#  '91b402ad7461c6087121e6f9d43ea818e154b6fd',
#  '9d58781a594705aa053f6a39a239f098af1a3b46',
#  'ec73d26cd3bd259fc3e12d8564ac84d99b61d1c8'}

# %%
s25.difference(s24)
# Out:
# {'8bb8c2f288ee2afdfb47010dc162ccd6d1062f7d',
#  '91b402ad7461c6087121e6f9d43ea818e154b6fd'}

# %%
#mas=[]
ps_utils.switch_to_dev()
r=ps.get('8f97fbd1299f6f5632affb0be6646df5fb6113b8')
for el in r.Result:
    try:
        s=el.StatusText
    except:
        s='None'
    if (s!='done'):
        print(ps.get(el._nonce)['_Counterparty'], el._id,s[0:65])
        #mas.append(ps.get(el._nonce)._id)
#mas
# Out:
# [INFO] 2023-06-08 12:15:51,242 - ps client switched from prod_pvlss to dev
# AVTTT 794289296f4a79d70201ea2fca47b0e02d9c87e6 signal: floating point exception (core dumped)
# RPZSO 4ff80e75ea6e15ab82a2cd3ad35f9da8063ee475 Repeated failures (5), last error: signal: floating point excepti
# SPPNA 71bd1ab3c3893b730b110baa86ad0857cbe29829 signal: floating point exception (core dumped)
# PTROL 2bc05a93e0188321dcd83784fa4864d3753df4e0 Unable to find index AI95K5_UFM_SPX_AVG in the static data set. w
# GODOV 17f7f536db75017cb0c07c37cdc5434d7d0e7fd1 None
# FSKSS dedd6d628ac19c17a795b3ebce2279f32b5c0dd0 Unable to find index RU_CPI_2000 in the static data set. while co
# MBDDR 9a1f29177a165b88166cbe65ef2ed570477c637c Unable to find index INRRUB in the static data set. while constru
# ISTRA 1bba957c31adff693dfd561f9463eec54782bb63 signal: floating point exception (core dumped)
# MASKL 122c55c49e042bf5bf84b82d60d92d54ee7c5485 signal: floating point exception (core dumped)
# KIRAN 26e4edee95006eee4c94724da3a63230998989ef signal: floating point exception (core dumped)
# EXTRE 98a0ecf61bdc4fed467caf70daf7548e9eed45ef None
# NIGOR 97f7e5a9b0b37e2513f6c0e4b19aa3432511711e signal: floating point exception (core dumped)
# PANMK dc88a42d5c45ae32d5da42cdbebb14f3705ca1f7 Unable to find index AEDRUB in the static data set. while constru
# SZBSS 9d6fcf84aabd551d6816dd48d1f78a8be04f9f76 signal: floating point exception (core dumped)
# PRIFR cd2431c4255b24da9770b7b87cfc18c52f61fa3b None
# EXCLS 8b836ebc34ba4eed689d95562308b6d382dd056a None
# UAIPR dccdcd80883a222683f0d2d259765918c3cf37ee None
# HTLFI 89f092e31b9cbb4506947d9b9dde79fba3f793d6 None
# BUSST 0e873c2cfe1223a738ad4f55c69b25413aae631d None
# PARUC 2bf27b5e8971a1342fc8e8e5119a34f7a630b23f None
# BASSN 79e6002011a2751c1eac7d4d714f8c92c8a60e69 signal: floating point exception (core dumped)
# POMRI 193cac9b851eed6791d0469e9cc32d9eb5a21d4a None

# %%
22260*0.05
# Out:
# 1113.0

# %%
r.Model.MarketDataSet.Spots['EURRUB']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-41bb69a18b11> in <module>
# ----> 1 r.Model.MarketDataSet.Spots['EURRUB']
#
# NameError: name 'r' is not defined

# %%
r=ps.get('1329ece514cc5041e3d1a34fc33aa36ea2cc6101')
#r.Product.NettingSets[0].MarginSets[1]['CSA']='123fb52aa9748c8cf42f5c4e96dffbb1603088fe'
ps_utils.compute(ps.put(r),algo_id='833aa9286a2951a0eac3fb38913d6990435e5c4c')
# Out:
# [INFO] 2023-06-23 11:39:31,558 - Compute:1329ece514cc5041e3d1a34fc33aa36ea2cc6101->40fd924b5e09f994d402d81e038fd963f84be949
# Dict([('BCVA', 342256.4178827792),
#       ('CVA', -27360.073004739785),
#       ('DVA', 369616.490887519),
#       ('ProductValue', -10508009.95689506),
#       ('ReportingCurrency', 'USD'),
#       ('StandardError', 49702.90608955732),
#       ('CashToSettleToday', 0.0)])

# %%
r=ps.get('1329ece514cc5041e3d1a34fc33aa36ea2cc6101')
r.Product.NettingSets[0].MarginSets[1]['CSA']='123fb52aa9748c8cf42f5c4e96dffbb1603088fe'
ps_utils.compute(ps.put(r),algo_id='833aa9286a2951a0eac3fb38913d6990435e5c4c')
# Out:
# [INFO] 2023-06-23 11:38:57,978 - Compute:64193523d047367621d6f49a96893d91f980bde2->7954c2ec500a26a806001df2286baadbd95234b9
# Dict([('BCVA', 157750.83596511622),
#       ('CVA', -69582.82411569265),
#       ('DVA', 227333.66008080886),
#       ('ProductValue', -10508009.95689506),
#       ('ReportingCurrency', 'USD'),
#       ('StandardError', 49702.90608955732),
#       ('CashToSettleToday', 0.0)])
